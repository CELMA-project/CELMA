# %% [markdown]
# # Exact solution used in MES runs
#
#
# We would like to MES the operation
#
# $$
# \partial_\theta^3 f
# $$
#
# Using cylindrical geometry.

# %%
# %matplotlib notebook

from sympy import init_printing
from sympy import S
from sympy import sin, cos, tanh, exp, pi, sqrt

from boutdata.mms import x, y, z, t
from boutdata.mms import DDZ

import os, sys
# If we add to sys.path, then it must be an absolute path
common_dir = os.path.abspath('./../../../')
# Sys path is a list of system paths
sys.path.append(common_dir)
from common.python.mesGenerator import get_metric, make_plot, BOUT_print

init_printing()

# %% [markdown]
# ## Initialize

# %%
folder = '../properZ/'
metric = get_metric()

# %% [markdown]
# ## Define the variables

# %%
# Initialization
the_vars = {}

# %% [markdown]
# ### Define the function to take the derivative of

# %% [markdown]
# **NOTE**:
#
# 1. z must be periodic
# 2. z must be of class infinity in $0$ and $2\pi$
# 3. x must be of class infinity in $0$
# 4. The field $f(\rho, \theta)$ must be continuous in the $\rho$ direction with $f(\rho, \theta + \pi)$
# 5. Eventual BC in $\rho$ must be satisfied

# %%
# We need Lx
from boututils.options import BOUTOptions
myOpts = BOUTOptions(folder)
Lx = eval(myOpts.geom['Lx'])

# %%
# Gaussian with sinus and parabola

# The skew sinus
# In cartesian coordinates we would like a sinus with with a wave-vector in the direction
# 45 degrees with respect to the first quadrant. This can be achieved with a wave vector
# k = [1/sqrt(2), 1/sqrt(2)]
# sin((1/sqrt(2))*(x + y))
# We would like 2 nodes, so we may write
# sin((1/sqrt(2))*(x + y)*(2*pi/(2*Lx)))
# Rewriting this to cylindrical coordinates, gives
# sin((1/sqrt(2))*(x*(cos(z)+sin(z)))*(2*pi/(2*Lx)))

# The gaussian
# In cartesian coordinates we would like
# f = exp(-(1/(2*w^2))*((x-x0)^2 + (y-y0)^2))
# In cylindrical coordinates, this translates to
# f = exp(-(1/(2*w^2))*(x^2 + y^2 + x0^2 + y0^2 - 2*(x*x0+y*y0) ))
#   = exp(-(1/(2*w^2))*(rho^2 + rho0^2 - 2*rho*rho0*(cos(theta)*cos(theta0)+sin(theta)*sin(theta0)) ))
#   = exp(-(1/(2*w^2))*(rho^2 + rho0^2 - 2*rho*rho0*(cos(theta - theta0)) ))

# A parabola
# In cartesian coordinates, we have
# ((x-x0)/Lx)^2
# Chosing this function to have a zero value at the edge yields in cylindrical coordinates
# ((x*cos(z)+Lx)/(2*Lx))^2

w = 0.8*Lx
rho0 = 0.3*Lx
theta0 = 5*pi/4
the_vars['f'] = sin((1/sqrt(2))*(x*(cos(z)+sin(z)))*(2*pi/(2*Lx)))*\
                exp(-(1/(2*w**2))*(x**2 + rho0**2 - 2*x*rho0*(cos(z - theta0)) ))*\
                ((x*cos(z)+Lx)/(2*Lx))**2

# %% [markdown]
# Calculating the solution

# %%
the_vars['S'] = DDZ(DDZ(DDZ(the_vars['f'], metric=metric), metric=metric), metric=metric)

# %% [markdown]
# ## Plot

# %%
make_plot(folder=folder, the_vars=the_vars, plot2d=True, include_aux=False)
# Out:
# <img src="data:image/png;base64,...">
# <img src="data:image/png;base64,...">
# <img src="data:image/png;base64,...">
# <img src="data:image/png;base64,...">

# %% [markdown]
# ## Print the variables in BOUT++ format

# %%
BOUT_print(the_vars, rational=False)
# Out:
# [S]
# -8.63057863295859e-6*sqrt(2)*pi^3*geom:xl^3*(geom:xl*cos(z)/60 + 1/2)^2*(-sin(z) + cos(z))^3*exp(-0.000868055555555556*geom:xl^2 - 0.015625*geom:xl*sin(z + pi/4))*cos(sqrt(2)*pi*geom:xl*(sin(z) + cos(z))/60) + 2.4273502405196e-5*pi^2*geom:xl^3*(geom:xl*cos(z)/60 + 1/2)^2*(-sin(z) + cos(z))^2*exp(-0.000868055555555556*geom:xl^2 - 0.015625*geom:xl*sin(z + pi/4))*sin(sqrt(2)*pi*geom:xl*(sin(z) + cos(z))/60)*cos(z + pi/4) + 1.13782042524356e-5*sqrt(2)*pi*geom:xl^3*(geom:xl*cos(z)/60 + 1/2)^2*(-sin(z) + cos(z))*exp(-0.000868055555555556*geom:xl^2 - 0.015625*geom:xl*sin(z + pi/4))*cos(sqrt(2)*pi*geom:xl*(sin(z) + cos(z))/60)*cos(z + pi/4)^2 - 3.55568882888614e-6*geom:xl^3*(geom:xl*cos(z)/60 + 1/2)^2*exp(-0.000868055555555556*geom:xl^2 - 0.015625*geom:xl*sin(z + pi/4))*sin(sqrt(2)*pi*geom:xl*(sin(z) + cos(z))/60)*cos(z + pi/4)^3 + 5.17834717977515e-5*pi^2*geom:xl^3*(geom:xl*cos(z)/60 + 1/2)*(-sin(z) + cos(z))^2*exp(-0.000868055555555556*geom:xl^2 - 0.015625*geom:xl*sin(z + pi/4))*sin(z)*sin(sqrt(2)*pi*geom:xl*(sin(z) + cos(z))/60) + 4.85470048103921e-5*sqrt(2)*pi*geom:xl^3*(geom:xl*cos(z)/60 + 1/2)*(-sin(z) + cos(z))*exp(-0.000868055555555556*geom:xl^2 - 0.015625*geom:xl*sin(z + pi/4))*sin(z)*cos(sqrt(2)*pi*geom:xl*(sin(z) + cos(z))/60)*cos(z + pi/4) - 2.27564085048713e-5*geom:xl^3*(geom:xl*cos(z)/60 + 1/2)*exp(-0.000868055555555556*geom:xl^2 - 0.015625*geom:xl*sin(z + pi/4))*sin(z)*sin(sqrt(2)*pi*geom:xl*(sin(z) + cos(z))/60)*cos(z + pi/4)^2 + 2.58917358988758e-5*sqrt(2)*pi*geom:xl^3*(-sin(z) + cos(z))*exp(-0.000868055555555556*geom:xl^2 - 0.015625*geom:xl*sin(z + pi/4))*sin(z)^2*cos(sqrt(2)*pi*geom:xl*(sin(z) + cos(z))/60) - 2.4273502405196e-5*geom:xl^3*exp(-0.000868055555555556*geom:xl^2 - 0.015625*geom:xl*sin(z + pi/4))*sin(z)^2*sin(sqrt(2)*pi*geom:xl*(sin(z) + cos(z))/60)*cos(z + pi/4) - 0.000517834717977515*pi^2*geom:xl^2*(geom:xl*cos(z)/60 + 1/2)^2*(-2*sin(z) - 2*cos(z))*(-sin(z) + cos(z))*exp(-0.000868055555555556*geom:xl^2 - 0.015625*geom:xl*sin(z + pi/4))*sin(sqrt(2)*pi*geom:xl*(sin(z) + cos(z))/60) - 0.000517834717977515*pi^2*geom:xl^2*(geom:xl*cos(z)/60 + 1/2)^2*(-sin(z) - cos(z))*(-sin(z) + cos(z))*exp(-0.000868055555555556*geom:xl^2 - 0.015625*geom:xl*sin(z + pi/4))*sin(sqrt(2)*pi*geom:xl*(sin(z) + cos(z))/60) - 0.000728205072155881*sqrt(2)*pi*geom:xl^2*(geom:xl*cos(z)/60 + 1/2)^2*(-sin(z) - cos(z))*exp(-0.000868055555555556*geom:xl^2 - 0.015625*geom:xl*sin(z + pi/4))*cos(sqrt(2)*pi*geom:xl*(sin(z) + cos(z))/60)*cos(z + pi/4) + 0.000728205072155881*sqrt(2)*pi*geom:xl^2*(geom:xl*cos(z)/60 + 1/2)^2*(-sin(z) + cos(z))*exp(-0.000868055555555556*geom:xl^2 - 0.015625*geom:xl*sin(z + pi/4))*sin(z + pi/4)*cos(sqrt(2)*pi*geom:xl*(sin(z) + cos(z))/60) - 0.000682692255146138*geom:xl^2*(geom:xl*cos(z)/60 + 1/2)^2*exp(-0.000868055555555556*geom:xl^2 - 0.015625*geom:xl*sin(z + pi/4))*sin(sqrt(2)*pi*geom:xl*(sin(z) + cos(z))/60)*sin(z + pi/4)*cos(z + pi/4) - 0.00155350415393255*sqrt(2)*pi*geom:xl^2*(geom:xl*cos(z)/60 + 1/2)*(-sin(z) - cos(z))*exp(-0.000868055555555556*geom:xl^2 - 0.015625*geom:xl*sin(z + pi/4))*sin(z)*cos(sqrt(2)*pi*geom:xl*(sin(z) + cos(z))/60) - 0.00155350415393255*sqrt(2)*pi*geom:xl^2*(geom:xl*cos(z)/60 + 1/2)*(-sin(z) + cos(z))*exp(-0.000868055555555556*geom:xl^2 - 0.015625*geom:xl*sin(z + pi/4))*cos(z)*cos(sqrt(2)*pi*geom:xl*(sin(z) + cos(z))/60) - 0.00145641014431176*geom:xl^2*(geom:xl*cos(z)/60 + 1/2)*exp(-0.000868055555555556*geom:xl^2 - 0.015625*geom:xl*sin(z + pi/4))*sin(z)*sin(sqrt(2)*pi*geom:xl*(sin(z) + cos(z))/60)*sin(z + pi/4) + 0.00145641014431176*geom:xl^2*(geom:xl*cos(z)/60 + 1/2)*exp(-0.000868055555555556*geom:xl^2 - 0.015625*geom:xl*sin(z + pi/4))*sin(sqrt(2)*pi*geom:xl*(sin(z) + cos(z))/60)*cos(z)*cos(z + pi/4) + 0.00155350415393255*geom:xl^2*exp(-0.000868055555555556*geom:xl^2 - 0.015625*geom:xl*sin(z + pi/4))*sin(z)*sin(sqrt(2)*pi*geom:xl*(sin(z) + cos(z))/60)*cos(z) + 0.0155350415393255*sqrt(2)*pi*geom:xl*(geom:xl*cos(z)/60 + 1/2)^2*(sin(z) - cos(z))*exp(-0.000868055555555556*geom:xl^2 - 0.0156 ...
#
# [f]
# 0.932102492359528*(geom:xl*cos(z)/60 + 1/2)^2*exp(-0.000868055555555556*geom:xl^2 - 0.015625*geom:xl*sin(z + pi/4))*sin(sqrt(2)*pi*geom:xl*(sin(z) + cos(z))/60)
